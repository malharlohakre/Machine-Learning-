# %%
#https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data
#https://archive.ics.uci.edu/static/public/10/data.csv

# %%
import pandas as pd
#column name-
columns=[
    "symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height",
    "curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","price"
]
#load url
url ="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
df = pd.read_csv(url,names=columns,na_values="?",sep=",",skipinitialspace=True,engine='python')#engine='python' its optional
df.head()
#df.to_csv("automobile.csv")# if you want data in offline
# Out:
#    symboling normalized-losses make fuel-type aspiration num-of-doors  \
# 3        NaN       alfa-romero  gas       std        two  convertible
# 3        NaN       alfa-romero  gas       std        two  convertible
# 1        NaN       alfa-romero  gas       std        two    hatchback
# 2      164.0              audi  gas       std       four        sedan
# 2      164.0              audi  gas       std       four        sedan
#
#   body-style drive-wheels  engine-location  wheel-base  ...  num-of-cylinders  \
# 3        rwd        front             88.6       168.8  ...               130
# 3        rwd        front             88.6       168.8  ...               130
# 1        rwd        front             94.5       171.2  ...               152
# 2        fwd        front             99.8       176.6  ...               109
# 2        4wd        front             99.4       176.6  ...               136
#
#    engine-size  fuel-system  bore stroke  compression-ratio horsepower  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 3 to -1
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          164 non-null    float64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         203 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    float64
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    int64
#  13  curb-weight        205 non-null    object
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    int64
# ...

# %%
df.describe()
# Out:
#         symboling  engine-location  wheel-base      length       width  \
# count  164.000000       205.000000  205.000000  205.000000  205.000000
# mean   122.000000        98.756585  174.049268   65.907805   53.724878
# std     35.442168         6.021776   12.337289    2.145204    2.443522
# min     65.000000        86.600000  141.100000   60.300000   47.800000
# 25%     94.000000        94.500000  166.300000   64.100000   52.000000
# 50%    115.000000        97.000000  173.200000   65.500000   54.100000
# 75%    150.000000       102.400000  183.100000   66.900000   55.500000
# max    256.000000       120.900000  208.100000   72.300000   59.800000
#
#             height  num-of-cylinders  fuel-system        bore      stroke  \
# count   205.000000        205.000000   201.000000  201.000000  205.000000
# mean   2555.565854        126.907317     3.329751    3.255423   10.142537
# std     520.680204         41.642693     0.273539    0.316717    3.972040
# ...

# %%
df.isna().sum()
# Out:
# symboling            41
# normalized-losses     0
# make                  0
# fuel-type             0
# aspiration            2
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           4
# bore                  4
# stroke                0
# compression-ratio     2
# horsepower            2
# peak-rpm              0
# city-mpg              0
# price                 4
# dtype: int64

# %%
df.shape
# Out:
# (205, 25)

# %%
data_unique = ['make','fuel-type','aspiration','num-of-doors','bore','body-style','drive-wheels',
               'engine-location','num-of-cylinders','fuel-system']
for col in data_unique:
    print(f'{col} : {df[col].unique()}')
# Out:
# make : ['gas' 'diesel']
# fuel-type : ['std' 'turbo']
# aspiration : ['two' 'four' nan]
# num-of-doors : ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# bore : [2.68 3.47 3.4  2.8  3.19 3.39 3.03 3.11 3.23 3.46 3.9  3.41 3.07 3.58
#  4.17 2.76 3.15  nan 3.16 3.64 3.1  3.35 3.12 3.86 3.29 3.27 3.52 2.19
#  3.21 2.9  2.07 2.36 2.64 3.08 3.5  3.54 2.87]
# body-style : ['rwd' 'fwd' '4wd']
# drive-wheels : ['front' 'rear']
# engine-location : [ 88.6  94.5  99.8  99.4 105.8  99.5 101.2 103.5 110.   88.4  93.7 103.3
#   95.9  86.6  96.5  94.3  96.  113.  102.   93.1  95.3  98.8 104.9 106.7
#  115.6  96.6 120.9 112.  102.7  93.   96.3  95.1  97.2 100.4  91.3  99.2
#  107.9 114.2 108.   89.5  98.4  96.1  99.1  93.3  97.   96.9  95.7 102.4
#  102.9 104.5  97.3 104.3 109.1]
# num-of-cylinders : [130 152 109 136 131 108 164 209  61  90  98 122 156  92  79 110 111 119
#  258 326  91  70  80 140 134 183 234 308 304  97 103 120 181 151 194 203
#  132 121 146 171 161 141 173 145]
# ...

# %%
#handling missing value
mean_fuel_system = df['fuel-system'].mean()
df['fuel-system'].fillna(mean_fuel_system,inplace=True)
print(df['fuel-system'].head())
# Out:
# 3    3.47
# 3    3.47
# 1    2.68
# 2    3.19
# 2    3.19
# Name: fuel-system, dtype: float64
# C:\Users\MALHAR\AppData\Local\Temp\ipykernel_17948\316227763.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fuel-system'].fillna(mean_fuel_system,inplace=True)

# %%
mean_bore = df['bore'].mean()
df['bore'].fillna(mean_bore,inplace=True)
print(df['bore'].head())
# Out:
# 3    2.68
# 3    2.68
# 1    3.47
# 2    3.40
# 2    3.40
# Name: bore, dtype: float64
# C:\Users\MALHAR\AppData\Local\Temp\ipykernel_17948\4065456524.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bore'].fillna(mean_bore,inplace=True)

# %%
mean_horsepower = df['horsepower'].mean()
df['horsepower'].fillna(mean_horsepower,inplace=True)
print(df['horsepower'].head())
# Out:
# 3    5000.0
# 3    5000.0
# 1    5000.0
# 2    5500.0
# 2    5500.0
# Name: horsepower, dtype: float64
# C:\Users\MALHAR\AppData\Local\Temp\ipykernel_17948\2984187281.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['horsepower'].fillna(mean_horsepower,inplace=True)

# %%
mean_price = df['price'].mean()
df['price'].fillna(mean_price,inplace=True)
print(df['price'].head())
# Out:
# 3    13495.0
# 3    16500.0
# 1    16500.0
# 2    13950.0
# 2    17450.0
# Name: price, dtype: float64
# C:\Users\MALHAR\AppData\Local\Temp\ipykernel_17948\3444492586.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(mean_price,inplace=True)

# %%
mode_aspiration = df['aspiration'].mode()[0]
df['aspiration'].fillna(mode_aspiration,inplace=True)
print(df['aspiration'].head())
# Out:
# 3     two
# 3     two
# 1     two
# 2    four
# 2    four
# Name: aspiration, dtype: object
# C:\Users\MALHAR\AppData\Local\Temp\ipykernel_17948\4155691144.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['aspiration'].fillna(mode_aspiration,inplace=True)

# %%
mean_compression_ratio = df['compression-ratio'].mean()
df['compression-ratio'].fillna(mean_compression_ratio,inplace=True)
print(df['compression-ratio'].head())
# Out:
# 3    111.0
# 3    111.0
# 1    154.0
# 2    102.0
# 2    115.0
# Name: compression-ratio, dtype: float64
# C:\Users\MALHAR\AppData\Local\Temp\ipykernel_17948\1499468100.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['compression-ratio'].fillna(mean_compression_ratio,inplace=True)

# %%
df.isna().sum()
# Out:
# symboling            41
# normalized-losses     0
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# price                 0
# dtype: int64

# %%
mean_symboling = df['symboling'].mean()
df['symboling'].fillna(mean_symboling,inplace=True)
print(df['symboling'].head())
# Out:
# 3    122.0
# 3    122.0
# 1    122.0
# 2    164.0
# 2    164.0
# Name: symboling, dtype: float64
# C:\Users\MALHAR\AppData\Local\Temp\ipykernel_17948\705218834.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['symboling'].fillna(mean_symboling,inplace=True)

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# price                0
# dtype: int64

# %%
df.to_csv("automobile.csv")# if you want data in offline
